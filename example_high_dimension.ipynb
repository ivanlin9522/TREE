# %%
import pandas as pd
import numpy as np
from prepare import *
from gurobipy import *
from MIP_solver import *
from MIP_solver_2 import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#y as a function of x
def fun_high(x):
    return -(x[:,0]-5)**2-(x[:,1]-5)**2-(x[:,2]-5)**2-(x[:,3]-5)**2-(x[:,4]-5)**2+125

# %%
seed=1
np.random.seed(seed)
x=5*np.random.rand(300,5)
x_add=2*np.random.rand(300,5)+1

# %%
x=np.vstack((x, x_add))
y=fun_high(x)

# %%
flag=1 #regression tree
rf=get_rf(x,y,3,flag)
trees=list()
trees=get_input(rf)

# %%
eta_1=0
eta_2=125
bisection(trees,flag,eta_1,eta_2,80)
# Out:
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
# Presolve added 0 rows and 22 columns
# Presolve removed 1113 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 0 rows, 1145 columns, 0 nonzeros
# Variable types: 1145 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.187123e+02, 0 iterations, 0.00 seconds
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      42.0005896   42.00059  0.00%     -   25s
#
# Cutting planes:
#   Lazy constraints: 3
#
# Explored 0 nodes (3 simplex iterations) in 25.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 42.0006
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.200058959220e+01, best bound 4.200058959220e+01, gap 0.0000%
# [0. 0. 0. 0. 0.]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [1e+02, 1e+02]
# Presolve added 3423 rows and 3426 columns
# Presolve time: 1.10s
# Presolved: 4536 rows, 4549 columns, 10284 nonzeros
# Presolved model has 2284 SOS constraint(s)
# Variable types: 2292 continuous, 2257 integer (2257 binary)
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1871233e+02   2.575512e+03   0.000000e+00     28s
#     3296    1.1871233e+02   0.000000e+00   0.000000e+00     28s
#
# Root relaxation: objective 1.187123e+02, 3296 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  465          -  118.71233      -     -   27s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#      0     0  118.71233    0  465          -  118.71233      -     -   38s
# H    0     0                      77.2579370  118.71233  53.7%     -   48s
#      0     0  118.71233    0  540   77.25794  118.71233  53.7%     -   48s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#      0     0  118.71233    0  540   77.25794  118.71233  53.7%     -   60s
#      0     2  118.71233    0  538   77.25794  118.71233  53.7%     -   60s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     43    46  118.71233    7  418   77.25794  118.71233  53.7%   127   71s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     77    45  118.71233    8  149   77.25794  118.71233  53.7%  94.0   81s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    137    58  118.71233    9  614   77.25794  118.71233  53.7%  68.3   93s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    174    65  117.89779   43 1078   77.25794  118.71233  53.7%  79.4  105s
# Find a violated constraint!
# Find a violated constraint!
# H  205    66                      81.8138885  118.71233  45.1%  69.7  116s
# Find a violated constraint!
# Find a violated constraint!
#    299    76 infeasible   14        81.81389  118.71233  45.1%  51.3  128s
# Find a violated constraint!
# Find a violated constraint!
#    327    79 infeasible   47        81.81389  118.71233  45.1%  48.8  139s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# *  399    79              83      94.6162681  118.71233  25.5%  40.5  161s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    598   112     cutoff   84        94.61627  118.71233  25.5%  31.0  187s
# Find a violated constraint!
# Find a violated constraint!
# *  617   104              73     100.5696024  118.71233  18.0%  32.8  198s
# Find a violated constraint!
# Find a violated constraint!
# *  618   101              73     102.2076603  118.71233  16.1%  32.8  208s
# Find a violated constraint!
# Find a violated constraint!
#    770   148 infeasible   11       102.20766  118.71233  16.1%  30.5  220s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    932   237  109.37263   31  456  102.20766  118.71233  16.1%  26.9  243s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# H  989   254                     102.9232629  118.71233  15.3%  26.4  276s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 1038   256              42     108.2302953  118.71233  9.68%  26.2  299s
# Find a violated constraint!
# Find a violated constraint!
#   1113   283     cutoff  178       108.23030  118.71233  9.68%  27.1  310s
# Find a violated constraint!
# * 1245   360              20     109.6734787  118.71233  8.24%  26.2  332s
# Find a violated constraint!
# Find a violated constraint!
#   1300   357  114.66077   86  395  109.67348  118.71233  8.24%  28.3  343s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1408   410  118.67459   10  788  109.67348  118.71233  8.24%  31.0  365s
# Find a violated constraint!
# Find a violated constraint!
# H 1431    58                     118.6745892  118.71233  0.03%  32.0  376s
# H 1619     0                     118.7123254  118.71233  0.00%  33.0  386s
#
# Cutting planes:
#   Implied bound: 9
#   Lazy constraints: 50
#
# Explored 1660 nodes (59485 simplex iterations) in 386.76 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 118.712 118.675 109.673 ... 77.2579
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187123254222e+02, best bound 1.187123254222e+02, gap 0.0000%
# [3.47197674 4.58808468 2.12543892 3.53264426 4.77902697]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [6e+01, 6e+01]
# Presolve added 3423 rows and 3426 columns
# Presolve time: 0.63s
# Presolved: 4536 rows, 4549 columns, 10284 nonzeros
# Presolved model has 2284 SOS constraint(s)
# Variable types: 2292 continuous, 2257 integer (2257 binary)
#
# Root relaxation: objective 1.187123e+02, 3229 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  450          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#      0     2  118.71233    0  450          -  118.71233      -     -   12s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     43    42  118.71233    7  386          -  118.71233      -   132   24s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     66    50  118.71233    7  325          -  118.71233      -   108   35s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     89    55 infeasible    8               -  118.71233      -  95.4   47s
# Find a violated constraint!
#    122    63 infeasible   26               -  118.71233      -  92.1   57s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    749   121 infeasible    6               -  118.71233      -  27.1   69s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1013   134  117.73732   11  500          -  118.71233      -  23.2   91s
# * 1238   162             157     103.4958273  118.71233  14.7%  23.6  102s
# Find a violated constraint!
# Find a violated constraint!
#   1426   233  111.19859   23    0  103.49583  118.71233  14.7%  25.7  118s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1435   239  116.11047   53    0  103.49583  118.71233  14.7%  25.6  131s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1521   282  111.98499   17  336  103.49583  118.71233  14.7%  33.1  172s
# Find a violated constraint!
# * 1557   242              19     116.2983958  118.71233  2.08%  34.1  185s
# Find a violated constraint!
# Find a violated constraint!
#   1593   190  116.32568   23   32  116.29840  118.71233  2.08%  34.5  199s
# Find a violated constraint!
# * 1599   180              21     118.6745892  118.71233  0.03%  34.4  212s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 13
#   Flow cover: 1
#   Lazy constraints: 12
#
# Explored 1628 nodes (58385 simplex iterations) in 212.38 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 118.675 116.298 103.496
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.186745892327e+02, best bound 1.186745892327e+02, gap 0.0000%
#
#  62.5
#
#
#  [3.47197674 2.88320111 2.12543892 3.17637442 5.        ]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [3e+01, 3e+01]
# Presolve added 3423 rows and 3426 columns
# Presolve time: 0.64s
# Presolved: 4536 rows, 4549 columns, 10284 nonzeros
# Presolved model has 2284 SOS constraint(s)
# Variable types: 2292 continuous, 2257 integer (2257 binary)
#
# Root relaxation: objective 1.187123e+02, 3229 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  450          -  118.71233      -     -    0s
#      0     2  118.71233    0  450          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    197    72  118.71233   19  739          -  118.71233      -  76.5   13s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1802   268  118.71233   20    0          -  118.71233      -  31.8   30s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1899   299  116.65300   21  253          -  118.71233      -  37.4   46s
# Find a violated constraint!
# Find a violated constraint!
#   2318   206 infeasible   53               -  118.71233      -  36.7   60s
# Find a violated constraint!
# Find a violated constraint!
#   2702   143   70.51372   37   12          -  118.71233      -  33.4   73s
# Find a violated constraint!
# Find a violated constraint!
#   2730   140  104.33974   85  148          -  118.71233      -  33.3   87s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 2925   116             101      71.4555664  118.71233  66.1%  31.5  113s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3198   217  101.08203  133   48   71.45557  118.71233  66.1%  31.1  127s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3407   310   92.28206  152    -   71.45557  118.71233  66.1%  31.2  153s
# Find a violated constraint!
# Find a violated constraint!
# * 3414   269              89      78.7984659  118.71233  50.7%  31.3  167s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3858   374   93.98579   42  267   78.79847  118.71233  50.7%  29.6  180s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4424   537   92.16876   30  444   78.79847  118.71233  50.7%  27.2  208s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4643   536   79.61767   63   10   78.79847  118.71233  50.7%  27.1  222s
# Find a violated constraint!
#   4971   560   82.91415   76    3   78.79847  118.71233  50.7%  26.5  235s
# Find a violated constraint!
# Find a violated constraint!
#   5036   612  103.56854   24  674   78.79847  118.71233  50.7%  26.4  248s
# Find a violated constraint!
# Find a violated constraint!
#   5457   741  103.56854   30  656   78.79847  118.71233  50.7%  25.6  262s
# Find a violated constraint!
#   5569   743   88.86750   24  118   78.79847  118.71233  50.7%  25.2  275s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6077   960  109.75856   45  302   78.79847  118.71233  50.7%  24.5  288s
# Find a violated constraint!
# Find a violated constraint!
#   6253  1067   89.15370   80    1   78.79847  118.71233  50.7%  24.4  302s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6403  1140     cutoff   81        78.79847  118.71233  50.7%  24.3  329s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# H 6434  1147                      81.2632711  118.71233  46.1%  24.4  342s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6435  1147   95.44023   73  402   81.26327  118.71233  46.1%  24.5  355s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6540  1164  113.57107   23  903   81.26327  118.71233  46.1%  24.2  369s
# Find a violated constraint!
# Find a violated constraint!
#   6940  1344  112.50587   24  499   81.26327  118.71233  46.1%  23.1  382s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7460  1610   92.19779   79  280   81.26327  118.71233  46.1%  22.3  409s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7700  1733  101.86593   28  570   81.26327  118.71233  46.1%  22.0  422s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 7797  1620              60      83.3160198  118.71233  42.5%  22.0  449s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7920  1703  114.85391   34    3   83.31602  118.71233  42.5%  22.0  476s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 8249  1676              33      86.9833652  118.71233  36.5%  21.6  502s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8907  1886  107.53026   36  460   86.98337  118.71233  36.5%  21.1  557s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 9097  1826             108      88.1755706  118.71233  34.6%  20.8  594s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9610  2091 infeasible  123        88.17557  118.71233  34.6%  20.0  648s
# Find a violated constraint!
# H 9611  1644                      92.4009281  118.71233  28.5%  20.0  661s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10249  1854  101.85196   34  762   92.40093  118.71233  28.5%  19.3  714s
# *10352  1859              55      92.6110483  118.71233  28.2%  19.3  727s
# Find a violated constraint!
# Find a violated constraint!
# H10482  1867                      93.3783076  118.71233  27.1%  19.2  753s
# Find a violated constraint!
# H10603  1584                      97.8619633  118.71233  21.3%  19.0  766s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11276  1775     cutoff   61        97.86196  118.71233  21.3%  18.9  800s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11639  1940  109.10237   29  912   97.86196  117.93643  20.5%  18.9  840s
# Find a violated constraint!
# Find a violated constraint!
#  12120  2087  103.05555   36  792   97.86196  117.03569  19.6%  19.1  853s
# Find a violated constraint!
# Find a violated constraint!
#  12824  2347     cutoff   50        97.86196  116.30354  18.8%  19.1  866s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  13611  2563 infeasible   29        97.86196  116.30354  18.8%  19.0  880s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  14362  2964     cutoff   24        97.86196  115.32195  17.8%  19.0  895s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  15198  3390 infeasible   49        97.86196  113.72323  16.2%  18.8  936s
# Find a violated constraint!
# *15344  2076              39     101.4906473  113.41218  11.7%  18.7  949s
#  16722  2412  103.34677   49  324  101.49065  111.78839  10.1%  18.5  950s
# Find a violated constraint!
#  18091  2765 infeasible   53       101.49065  111.18661  9.55%  17.9  963s
#  20848  3642  101.53724   60   93  101.49065  110.89280  9.26%  16.6  965s
# Find a violated constraint!
# *23567  1805              59     101.9990172  107.42931  5.32%  17.2  979s
#  25192  1589  107.10153   58  203  101.99902  107.10153  5.00%  17.2  980s
#
# Cutting planes:
#   Lazy constraints: 114
#
# Explored 29906 nodes (491729 simplex iterations) in 982.67 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 101.999 101.491 97.862 ... 81.2633
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.019990171629e+02, best bound 1.019990171629e+02, gap 0.0000%
#
#  31.25
#
#
#  [1.60961805 2.76369356 2.12543892 3.63394545 1.77087806]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [2e+01, 2e+01]
# Presolve added 3195 rows and 3198 columns
# Presolve time: 0.61s
# Presolved: 4308 rows, 4321 columns, 9831 nonzeros
# Presolved model has 2130 SOS constraint(s)
# Variable types: 2215 continuous, 2106 integer (2106 binary)
#
# Root relaxation: objective 1.187123e+02, 3118 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  303          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#      0     2  118.71233    0  303          -  118.71233      -     -   11s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     31    27  118.71233    6 1197          -  118.71233      -   109   24s
#    458    75 infeasible   72               -  118.71233      -  36.1   25s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1299   170  118.71233   11  409          -  118.71233      -  25.9   36s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   2335   398   95.63195  165  140          -  118.71233      -  21.7   48s
#   2712   459  108.06747   59    0          -  118.71233      -  20.3   52s
#   2763   469  118.71233   19  490          -  118.71233      -  23.8   55s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 3329   331              56      67.8595513  118.71233  74.9%  23.3   82s
# Find a violated constraint!
# Find a violated constraint!
# * 3416   270              54      71.1073152  118.71233  66.9%  22.9   96s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3480   279  118.71233   62  160   71.10732  118.71233  66.9%  22.7  124s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3638   330 infeasible   82        71.10732  118.71233  66.9%  22.2  137s
# Find a violated constraint!
# Find a violated constraint!
# H 3685   284                      75.3137605  118.71233  57.6%  22.0  151s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4229   604  106.37415   24  461   75.31376  118.71233  57.6%  20.1  164s
# Find a violated constraint!
# Find a violated constraint!
#   4273   609  101.86822  139   43   75.31376  118.71233  57.6%  20.0  178s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4504   790   94.66820  144    -   75.31376  118.71233  57.6%  19.4  204s
# Find a violated constraint!
# Find a violated constraint!
#   4634   864   89.05796  144    9   75.31376  118.71233  57.6%  19.5  218s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4789   940     cutoff  145        75.31376  118.71233  57.6%  19.4  245s
# Find a violated constraint!
# Find a violated constraint!
#   4843   960   84.72674   36    -   75.31376  118.71233  57.6%  19.4  258s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4979  1018  100.63244   33  145   75.31376  118.71233  57.6%  19.1  272s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5029  1032     cutoff   52        75.31376  118.71233  57.6%  19.1  299s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# H 5042  1041                      75.5402014  118.71233  57.2%  19.1  325s
# Find a violated constraint!
# Find a violated constraint!
#   5056  1039   86.34497   37   38   75.54020  118.71233  57.2%  19.0  338s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 5135   978              77      77.1815548  118.71233  53.8%  19.1  352s
# Find a violated constraint!
# Find a violated constraint!
# * 5183   900              80      81.6514714  118.71233  45.4%  19.0  366s
#   5197   920   88.98082  116    0   81.65147  118.71233  45.4%  19.0  371s
#   5208   930  118.71233   23  638   81.65147  118.71233  45.4%  20.8  375s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5454  1000  113.05963   37  334   81.65147  118.71233  45.4%  22.8  394s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5558  1016  108.29629   42  335   81.65147  118.71233  45.4%  23.3  409s
# Find a violated constraint!
# Find a violated constraint!
#   5654  1040  104.99774   48  110   81.65147  118.71233  45.4%  23.9  422s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6032  1037 infeasible   74        81.65147  118.71233  45.4%  24.6  437s
# Find a violated constraint!
# Find a violated constraint!
#   6114  1040  118.71233   82   11   81.65147  118.71233  45.4%  24.8  450s
#   6293  1015   91.27772   50    0   81.65147  118.71233  45.4%  24.7  456s
#   6302  1021  102.63742   62   66   81.65147  118.71233  45.4%  24.7  460s
#   6335  1050   97.13635   38  280   81.65147  118.71233  45.4%  26.6  465s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6554  1096   85.48923   51  225   81.65147  118.71233  45.4%  27.5  479s
# Find a violated constraint!
# Find a violated constraint!
# * 6565  1032              53      82.4077284  118.71233  44.1%  27.5  492s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6718  1046  115.04466   39  488   82.40773  118.71233  44.1%  27.5  506s
# Find a violated constraint!
# Find a violated constraint!
#   6751  1047  115.04466   40  662   82.40773  118.71233  44.1%  27.4  520s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6898  1050   90.17933   46  260   82.40773  118.71233  44.1%  27.5  533s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 6927  1011              49      82.4465537  118.71233  44.0%  27.5  559s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7071  1045   93.56975   41  686   82.44655  117.81434  42.9%  27.5  573s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7155  1047     cutoff   45        82.44655  117.52761  42.6%  27.5  586s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7214  1074  113.82578   45    0   82.44655  117.52761  42.6%  27.4  605s
#   7225  1081   84.07340   62  500   82.44655  117.52761  42.6%  27.4  610s
#   7233  1088   87.06955   54   17   82.44655  117.52761  42.6%  30.2  615s
#   7246  1098   93.91862   44    0   82.44655  117.52761  42.6%  32.9  621s
#   7253  1104   87.06955   54    0   82.44655  117.52761  42.6%  34.0  626s
#   7259  1108   87.59349   63  996   82.44655  117.52579  42.5%  33.9  630s
#   7267  1115   93.94676   53  966   82.44655  117.43816  42.4%  35.4  635s
#   7273  1120   87.06955   54  561   82.44655  117.38854  42.4%  36.6  640s
#   7281  1127   89.21278   58  699   82.44655  117.29742  42.3%  37.9  645s
#   7291  1134   87.57158   46  718   82.44655  117.18544  42.1%  37.8  650s
#   7296  1140     cutoff  117        82.44655  117.13927  42.1%  40.3  656s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7992  1239     cutoff  145        82.44655  115.04466  39.5%  41.9  685s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8333  1269   89.55725  125  234   82.44655  115.04466  39.5%  41.6  700s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8395  1301   83.76985  184    4   82.44655  115.04466  39.5%  41.5  713s
# Find a violated constraint!
# Find a violated constraint!
#   8455  1292   94.52609  131   99   82.44655  115.04466  39.5%  41.5  726s
# Find a violated constraint!
# Find a violated constraint!
#   8725  1330   88.97631  129  425   82.44655  114.60572  39.0%  41.2  740s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8898  1347  107.08193  122 1127   82.44655  109.16864  32.4%  41.2  753s
# Find a violated constraint!
# Find a violated constraint!
#   9106  1389   92.97789  141   24   82.44655  107.07566  29.9%  41.3  767s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9383  1405     cutoff  139        82.44655  107.07566  29.9%  41.1  780s
# Find a violated constraint!
# Find a violated constraint!
#  10136  1378 infeasible  143        82.44655  105.21388  27.6%  40.1  794s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10484  1332   83.40420  146   12   82.44655  103.03489  25.0%  39.5  834s
# Find a violated constraint!
# Find a violated constraint!
#  10500  1346     cutoff  135        82.44655  103.03489  25.0%  39.6  847s
# Find a violated constraint!
# Find a violated constraint!
#  10768  1354   82.47351  156    -   82.44655  102.14183  23.9%  39.5  860s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11073  1435   83.39826  154    4   82.44655  102.14183  23.9%  39.4  887s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11327  1488   85.21500  132  163   82.44655  100.60386  22.0%  39.4  927s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11400  1523   92.17029  132  256   82.44655  100.60386  22.0%  39.3  940s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11551  1538   82.62867  144    2   82.44655   99.15527  20.3%  39.1  967s
# Find a violated constraint!
# Find a violated constraint!
#  11727  1566 infeasible  127        82.44655   99.15527  20.3%  39.7  980s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  12579  1715     cutoff  139        82.44655   96.22397  16.7%  39.7 1032s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  12754  1805   86.27103  127   99   82.44655   96.10055  16.6%  39.4 1058s
# *12760  1057             138      84.9476594   96.10055  13.1%  39.4 1069s
#  12824  1020     cutoff  145        84.94766   96.10055  13.1%  39.4 1071s
# Find a violated constraint!
#  13164   952 infeasible  156        84.94766   94.50268  11.2%  39.9 1083s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  14595   925     cutoff  156        84.94766   90.70642  6.78%  39.3 1097s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  16520  1129   85.79482  123 1120   84.94766   89.90351  5.83%  36.3 1113s
# Find a violated constraint!
#  17634  1030     cutoff  170        84.94766   89.90351  5.83%  34.8 1129s
# Find a violated constraint!
# Find a violated constraint!
#  18645  1167     cutoff  164        84.94766   89.90351  5.83%  33.9 1143s
#  19679   284     cutoff  135        84.94766   86.22728  1.51%  32.9 1145s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 4
#   Implied bound: 49
#   Clique: 230
#   MIR: 80
#   Flow cover: 885
#   Lazy constraints: 75
#
# Explored 20169 nodes (656621 simplex iterations) in 1145.57 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 84.9477 82.4466 82.4077 ... 67.8596
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.494765937027e+01, best bound 8.494765937027e+01, gap 0.0000%
#
#  15.625
#
#
#  [1.60961805 1.57182931 2.12603229 1.87475895 1.59020375]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [8e+00, 8e+00]
# Presolve added 2597 rows and 2603 columns
# Presolve time: 0.63s
# Presolved: 3710 rows, 3726 columns, 9041 nonzeros
# Presolved model has 1728 SOS constraint(s)
# Variable types: 2015 continuous, 1711 integer (1711 binary)
#
# Root relaxation: objective 1.187123e+02, 2758 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  192          -  118.71233      -     -    0s
#      0     0  118.71233    0  222          -  118.71233      -     -    0s
#      0     0  118.71233    0  222          -  118.71233      -     -    0s
#      0     2  118.71233    0  222          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     63    44 infeasible    9               -  118.71233      -  52.8   13s
#   1125   236  118.71233   35    0          -  118.71233      -  20.6   16s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   1820    76   41.20530   55    3          -  118.71233      -  18.0   31s
# * 1925    76              55      41.2052982  118.71233   188%  17.7   44s
# Find a violated constraint!
# Find a violated constraint!
# * 2251   211              80      43.2793145  118.71233   174%  16.3   69s
#   2938   367 infeasible   47        43.27931  118.71233   174%  14.0   70s
# Find a violated constraint!
# * 3280   470              84      45.0580631  118.71233   163%  12.9   83s
# Find a violated constraint!
#   4151   678 infeasible   35        45.05806  118.71233   163%  10.8   96s
# Find a violated constraint!
#   4464   746   69.22390   75   42   45.05806  118.71233   163%  10.1  109s
# * 4603   763              86      49.3360862  118.71233   141%   9.9  122s
# Find a violated constraint!
# Find a violated constraint!
# * 5632   944              78      51.4101025  118.71233   131%   8.6  136s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5805  1083  111.04698   46   55   51.41010  118.71233   131%   9.1  150s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5840  1117   69.89360   30   85   51.41010  118.71233   131%   9.3  164s
# Find a violated constraint!
# Find a violated constraint!
#   6008  1195   85.68254   71   20   51.41010  118.71233   131%   9.4  177s
# Find a violated constraint!
#   6088  1247   85.68254   81    3   51.41010  118.71233   131%   9.6  190s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6157  1293   76.74412  123   31   51.41010  118.71233   131%   9.5  217s
# Find a violated constraint!
# * 6193  1158              98      65.6569366  118.71233  80.8%   9.5  229s
# Find a violated constraint!
# * 6194  1144              98      66.6942134  118.71233  78.0%   9.5  242s
# Find a violated constraint!
# Find a violated constraint!
#   6422  1260     cutoff   51        66.69421  118.71233  78.0%  10.5  256s
# * 6467  1136             148      68.0130560  118.71233  74.5%  10.4  269s
# Find a violated constraint!
# Find a violated constraint!
#   7111  1517   86.32450   27  206   68.01306  118.71233  74.5%  10.0  282s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7589  1696   82.99559   28  146   68.01306  118.71233  74.5%   9.6  296s
# Find a violated constraint!
# Find a violated constraint!
#   7796  1808   70.45290   61    4   68.01306  118.71233  74.5%   9.8  309s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7807  1813   70.53906  211    -   68.01306  118.71233  74.5%   9.8  336s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8281  1934     cutoff   65        68.01306  118.71233  74.5%   9.5  350s
# Find a violated constraint!
# * 8298  1924             211      68.4769332  118.71233  73.4%   9.5  363s
#   8493  1989   83.60550   83    0   68.47693  118.71233  73.4%   9.5  368s
#   8500  1994   73.99642   50  196   68.47693  118.71233  73.4%   9.5  370s
#   8519  2010  100.62664   38  606   68.47693  118.71233  73.4%  11.1  375s
# Find a violated constraint!
#   8813  2083   81.35057   45  212   68.47693  118.68610  73.3%  12.5  391s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9286  2088 infeasible   90        68.47693  118.68610  73.3%  13.6  405s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9515  2129   74.72312   50    0   68.47693  112.02328  63.6%  13.8  439s
#   9517  2130   75.92693   48   28   68.47693  112.02328  63.6%  13.8  441s
#   9529  2140   83.24668   49    0   68.47693  112.02328  63.6%  14.6  446s
#   9540  2147   71.87885   74  124   68.47693  112.02328  63.6%  14.6  450s
#   9557  2160   75.92693   48    0   68.47693  112.02328  63.6%  15.7  455s
#   9571  2173   71.87885   76    0   68.47693  112.02328  63.6%  17.4  461s
#   9578  2179   77.51017   44    0   68.47693  112.02328  63.6%  18.1  466s
#   9585  2185   68.58231   62    0   68.47693  112.02328  63.6%  19.0  470s
#   9599  2197  105.49869  128  659   68.47693  112.02328  63.6%  20.1  476s
#   9662  2229   79.39120  133  643   68.47693  105.18021  53.6%  20.5  480s
# Find a violated constraint!
#   9828  2278   82.50911  134  364   68.47693  103.29704  50.8%  20.5  493s
# Find a violated constraint!
# Find a violated constraint!
# * 9972  2164             155      72.1850364   96.40618  33.6%  20.4  520s
# Find a violated constraint!
# Find a violated constraint!
#  10090  2131   73.70791  134  377   72.18504   96.10407  33.1%  20.4  533s
# Find a violated constraint!
# Find a violated constraint!
#  10159  2123 infeasible  135        72.18504   94.69904  31.2%  20.4  547s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10177  2128   75.40903  132  751   72.18504   94.69904  31.2%  20.4  560s
# Find a violated constraint!
#  10223  2102   88.78146  135  454   72.18504   94.69904  31.2%  20.3  573s
# Find a violated constraint!
#  10273  2098   89.17414  136  898   72.18504   89.55240  24.1%  20.4  587s
# Find a violated constraint!
# Find a violated constraint!
#  10466  2048   79.21456  167    -   72.18504   87.86761  21.7%  20.5  601s
# Find a violated constraint!
# Find a violated constraint!
#  10870  1874   72.18931  147   43   72.18504   81.14690  12.4%  20.3  615s
# *11117  1636             155      73.2107688   81.14690  10.8%  20.0  628s
# Find a violated constraint!
# Find a violated constraint!
#  11353  1452   78.85946  140  251   73.21077   81.14690  10.8%  19.7  642s
# Find a violated constraint!
# Find a violated constraint!
# H11444  1298                      74.2234650   81.07686  9.23%  19.7  667s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   Implied bound: 18
#   Clique: 1166
#   MIR: 12
#   Flow cover: 433
#   GUB cover: 5
#   Lazy constraints: 19
#
# Explored 11516 nodes (228699 simplex iterations) in 667.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 74.2235 73.2108 72.185 ... 45.0581
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.422346498821e+01, best bound 7.422346498821e+01, gap 0.0000%
#
#  7.8125
#
#
#  [1.25311124 1.71099375 1.7354462  0.         0.        ]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [1e+01, 1e+01]
# Presolve added 2943 rows and 2946 columns
# Presolve time: 0.54s
# Presolved: 4056 rows, 4069 columns, 9309 nonzeros
# Presolved model has 1960 SOS constraint(s)
# Variable types: 2130 continuous, 1939 integer (1939 binary)
#
# Root relaxation: objective 1.187123e+02, 2907 iterations, 0.03 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  314          -  118.71233      -     -    0s
#      0     2  118.71233    0  314          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    127    66  118.71233   14  392          -  118.71233      -  32.6   11s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#    358    77 infeasible   52               -  118.71233      -  13.1   23s
# Find a violated constraint!
# Find a violated constraint!
#   1001    88   92.40158  134  226          -  118.71233      -   6.5   34s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 1914   106             205      53.5071392  118.71233   122%   4.1   57s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 1946    97             275      63.4508163  118.71233  87.1%   4.3   68s
#   2117   111  118.71233   15    0   63.45082  118.71233  87.1%   5.2   72s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   2184   135   97.13587   21  235   63.45082  118.71233  87.1%   9.3   87s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   2304   160  112.05246   23  196   63.45082  118.71233  87.1%  12.4  101s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3172   235  118.46612   22  582   63.45082  118.71233  87.1%  10.7  116s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   3437   266   68.03400  110   39   63.45082  118.71233  87.1%  10.5  130s
# Find a violated constraint!
# Find a violated constraint!
#   3686   296 infeasible  121        63.45082  118.71233  87.1%  10.3  143s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 3843   307              90      75.2715168  118.71233  57.7%  10.1  169s
#   3979   304  115.04466   21  392   75.27152  118.71233  57.7%   9.9  170s
# Find a violated constraint!
# * 4029   312              90      75.5143275  118.71233  57.2%   9.9  183s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4035   316   96.19678   65    2   75.51433  118.71233  57.2%   9.9  196s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4175   369   98.77008   21  415   75.51433  118.71233  57.2%   9.8  223s
# Find a violated constraint!
# Find a violated constraint!
#   4241   379  102.85358   27  688   75.51433  118.71233  57.2%  10.0  237s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4479   460   78.31482   25  242   75.51433  118.71233  57.2%  10.1  250s
# Find a violated constraint!
#   4690   546 infeasible   35        75.51433  118.71233  57.2%  10.0  263s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 4747   528              71      78.0664703  118.71233  52.1%   9.9  289s
# Find a violated constraint!
# Find a violated constraint!
#   5007   580  115.54855   24  456   78.06647  118.71233  52.1%  10.2  303s
# Find a violated constraint!
# Find a violated constraint!
#   5147   624  112.37338   25  491   78.06647  118.71233  52.1%  10.3  316s
#   5279   652   89.88853   27    0   78.06647  118.71233  52.1%  10.4  321s
#   5291   665  109.19089   31 1262   78.06647  118.71233  52.1%  11.6  325s
# Find a violated constraint!
# Find a violated constraint!
#   5457   726   98.71837   40  178   78.06647  117.37367  50.4%  14.6  342s
#   6233   700   95.72394   39    0   78.06647  115.47654  47.9%  16.2  348s
#   6239   704   88.95856   45    0   78.06647  115.47654  47.9%  16.2  350s
#   6275   732  113.75804   49 1377   78.06647  115.47654  47.9%  17.7  355s
#   7182   870   84.09919   64    0   78.06647  115.47654  47.9%  21.1  362s
#   7194   878   93.97832   56   12   78.06647  115.47654  47.9%  21.0  365s
#   7197   883  115.47654   59 1997   78.06647  115.47654  47.9%  22.8  375s
#   7227   909   88.98703   63 1332   78.06647  115.39173  47.8%  23.3  380s
# Find a violated constraint!
# Find a violated constraint!
#   7628   932     cutoff   67        78.06647  114.76250  47.0%  23.7  396s
#   8467   867   92.14956   69    0   78.06647  114.53675  46.7%  23.0  403s
#   8471   870   82.21037   69  634   78.06647  114.53675  46.7%  23.0  405s
#   8480   877   78.86318   72    0   78.06647  114.53675  46.7%  24.6  410s
#   8491   886   82.21037   69    0   78.06647  114.53675  46.7%  26.0  417s
#   8497   890   82.49440   69 1032   78.06647  114.53675  46.7%  26.0  420s
#   8505   896  100.54572   65  607   78.06647  114.53675  46.7%  27.4  425s
#   8514   904   87.46793   67   24   78.06647  114.53675  46.7%  28.6  430s
#   8522   910  104.61972   66  311   78.06647  114.53675  46.7%  29.9  435s
#   8531   916   82.21037   69 1032   78.06647  114.53675  46.7%  29.9  440s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8861  1000   97.55297  138  362   78.06647  113.56773  45.5%  32.1  457s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8907  1003   97.55297  139  345   78.06647  109.17754  39.9%  32.1  471s
# Find a violated constraint!
# Find a violated constraint!
#   9085  1067   84.37203  150   46   78.06647  109.17754  39.9%  32.1  485s
# Find a violated constraint!
# Find a violated constraint!
#   9150  1079   92.60019  151   89   78.06647  109.17754  39.9%  32.0  498s
# Find a violated constraint!
#   9241  1098   93.21359  154   98   78.06647  109.17754  39.9%  32.0  511s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9594  1165   81.21179  164   33   78.06647  109.17754  39.9%  31.6  526s
# Find a violated constraint!
# Find a violated constraint!
#   9825  1137     cutoff  175        78.06647  105.14518  34.7%  31.2  540s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10458  1020     cutoff  148        78.06647   98.67061  26.4%  30.2  568s
# Find a violated constraint!
# *10487   841             181      79.5298176   95.96218  20.7%  30.2  581s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10550   814   79.68023  144  302   79.52982   95.96218  20.7%  30.1  596s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10827   760   82.71181  157   13   79.52982   91.84987  15.5%  29.9  610s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11084   709     cutoff  166        79.52982   91.12224  14.6%  29.6  624s
#  11276   651 infeasible  142        79.52982   90.26081  13.5%  29.5  625s
# ...
# Find a violated constraint!
# Find a violated constraint!
#   7032  1407     cutoff  145        74.30702  106.20888  42.9%  38.3  603s
# Find a violated constraint!
# Find a violated constraint!
# * 7050  1308             168      74.9111279  106.20888  41.8%  38.2  616s
# Find a violated constraint!
# Find a violated constraint!
# * 7051  1190             168      75.7500662  106.20888  40.2%  38.2  628s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7159  1184     cutoff  150        75.75007  106.20888  40.2%  38.0  654s
# Find a violated constraint!
#   7199  1189     cutoff  140        75.75007  106.20888  40.2%  38.1  666s
# Find a violated constraint!
# Find a violated constraint!
# * 7287  1098             159      77.6313849  104.61972  34.8%  38.2  690s
# Find a violated constraint!
# Find a violated constraint!
#   7464  1100     cutoff  140        77.63138  100.80005  29.8%  37.7  702s
# Find a violated constraint!
# Find a violated constraint!
#   7547  1089     cutoff  151        77.63138   98.97719  27.5%  37.7  715s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7664  1074   86.63125  134  139   77.63138   98.83446  27.3%  37.5  727s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7821  1084     cutoff  162        77.63138   96.53530  24.4%  37.1  740s
# Find a violated constraint!
# H 7908   978                      78.0956491   96.53530  23.6%  36.9  752s
# Find a violated constraint!
# Find a violated constraint!
#   8155   980   85.50392  142  207   78.09565   92.50178  18.4%  36.3  765s
# Find a violated constraint!
#   8263   972   85.98808  136  318   78.09565   92.44489  18.4%  36.3  777s
# Find a violated constraint!
#   8475   968   88.50920  164   26   78.09565   92.44489  18.4%  36.0  789s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8506   982   92.44489  136  191   78.09565   92.44489  18.4%  35.8  802s
# Find a violated constraint!
#   8708  1029   81.83377  179    3   78.09565   92.44489  18.4%  35.1  814s
# Find a violated constraint!
# * 8943   802             141      78.9777931   92.44489  17.1%  34.8  826s
# Find a violated constraint!
# Find a violated constraint!
#   9262   620     cutoff  149        78.97779   88.88346  12.5%  34.0  838s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   9690   618   79.12883  159    5   78.97779   86.83787  10.0%  33.4  851s
# Find a violated constraint!
# Find a violated constraint!
# * 9806   559             185      79.5298176   86.48417  8.74%  33.1  864s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10341   436     cutoff  149        79.52982   84.37573  6.09%  32.2  877s
# Find a violated constraint!
# Find a violated constraint!
#  10627   528     cutoff  145        79.52982   83.56746  5.08%  31.5  889s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10974   399   79.73537  155    6   79.52982   82.34588  3.54%  31.2  902s
# Find a violated constraint!
# Find a violated constraint!
#  11230   368   80.01235  159    6   79.52982   81.42185  2.38%  31.1  914s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# *11244   367             159      79.5954024   81.42185  2.29%  31.1  927s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  11723   205   79.78790  148  127   79.59540   80.91787  1.66%  30.1  940s
# Find a violated constraint!
# Find a violated constraint!
# *11809     9             142      80.1557876   80.91787  0.95%  29.9  952s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 10
#   Implied bound: 62
#   Clique: 214
#   MIR: 33
#   Flow cover: 708
#   GUB cover: 2
#   Zero half: 1
#   Lazy constraints: 57
#
# Explored 11945 nodes (357799 simplex iterations) in 952.82 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 80.1558 79.5954 79.5298 ... 73.3743
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.015578758964e+01, best bound 8.015578758964e+01, gap 0.0000%
#
#  11.7645263671875
#
#
#  [1.85946463 0.         2.12543892 1.23461495 1.50504252]
#
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 1113 rows, 1123 columns and 2223 nonzeros
# Model has 1 quadratic constraint
# Model has 2284 general constraints
# Variable types: 8 continuous, 1115 integer (1115 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+02, 1e+02]
#   QRHS range       [1e+01, 1e+01]
# Presolve added 2943 rows and 2946 columns
# Presolve time: 0.52s
# Presolved: 4056 rows, 4069 columns, 9300 nonzeros
# Presolved model has 1960 SOS constraint(s)
# Variable types: 2130 continuous, 1939 integer (1939 binary)
#
# Root relaxation: objective 1.187123e+02, 2918 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  118.71233    0  269          -  118.71233      -     -    0s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#      0     2  118.71233    0  269          -  118.71233      -     -   10s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#     39    32  118.71233    7  899          -  118.71233      -   116   20s
# Find a violated constraint!
# Find a violated constraint!
#   1691    70  118.71233  145  247          -  118.71233      -  10.2   31s
# Find a violated constraint!
#   2171   102 infeasible  167               -  118.71233      -  10.7   40s
#   3617   160   86.72292   11    0          -  118.71233      -   8.7   45s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   4923   452   63.07576  114    9          -  118.71233      -  19.7   59s
# * 4940   452             122      57.0340375  118.71233   108%  19.7   71s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5455   807   63.65614   50   13   57.03404  118.71233   108%  20.3  120s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# H 5493   735                      59.2857487  118.71233   100%  20.2  132s
# Find a violated constraint!
# Find a violated constraint!
#   5725   831  101.28259   19  406   59.28575  118.71233   100%  20.0  145s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   5829   863   73.20634   21  100   59.28575  118.71233   100%  20.2  170s
# Find a violated constraint!
#   5899   921     cutoff   42        59.28575  118.71233   100%  20.3  182s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# * 5979   922              35      64.0566240  118.71233  85.3%  20.5  218s
# Find a violated constraint!
#   6121   944 infeasible   53        64.05662  118.71233  85.3%  20.8  230s
# * 6232   986              44      64.1987027  118.71233  84.9%  21.4  242s
# * 6296  1000              51      64.9115408  118.71233  82.9%  21.5  254s
# Find a violated constraint!
# Find a violated constraint!
# * 6305  1001              75      65.3688402  118.71233  81.6%  21.6  266s
# Find a violated constraint!
# Find a violated constraint!
#   6370  1011   70.74103   32   48   65.36884  118.71233  81.6%  21.9  278s
# Find a violated constraint!
#   6430  1034   91.59411   34  250   65.36884  118.71233  81.6%  22.7  290s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6516  1054 infeasible   44        65.36884  118.71233  81.6%  22.9  315s
# Find a violated constraint!
# * 6622   993              61      66.9596071  118.71233  77.3%  23.0  327s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   6885  1021  118.71233   25  250   66.95961  118.71233  77.3%  23.1  340s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   7035  1058     cutoff  135        66.95961  118.71233  77.3%  23.8  353s
# Find a violated constraint!
# Find a violated constraint!
# * 7161  1065              32      67.0135334  118.71233  77.1%  24.2  377s
# Find a violated constraint!
# Find a violated constraint!
# * 7633  1145             123      69.8261944  118.71233  70.0%  23.7  389s
#   7664  1159  118.71233   77  195   69.82619  118.71233  70.0%  23.7  390s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8416  1804  112.77757   66  704   69.82619  118.71233  70.0%  24.0  403s
#   8627  1960  118.71233   29    0   69.82619  118.71233  70.0%  24.4  407s
#   8765  1979 infeasible   35        69.82619  118.71233  70.0%  25.5  410s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#   8808  1968 infeasible   37        69.82619  118.71233  70.0%  25.4  423s
#   9166  1899  118.71233   40  573   69.82619  118.71233  70.0%  25.0  425s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10053  1677  118.71233   43  443   69.82619  118.71233  70.0%  23.3  438s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# *10196  1561             110      74.6757641  118.71233  59.0%  23.2  463s
# Find a violated constraint!
# Find a violated constraint!
#  10257  1549  100.98440  131    7   74.67576  118.71233  59.0%  23.2  476s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  10387  1584   85.06230  133    0   74.67576  118.71233  59.0%  23.0  505s
#  10505  1635   96.01396   48  245   74.67576  118.71233  59.0%  24.4  510s
# Find a violated constraint!
# Find a violated constraint!
#  11231  1751   88.89288   56   76   74.67576  118.71233  59.0%  24.5  523s
# Find a violated constraint!
# Find a violated constraint!
#  11463  1734 infeasible   45        74.67576  118.71233  59.0%  24.2  535s
# Find a violated constraint!
# Find a violated constraint!
# *11508  1628              81      76.9642920  118.71233  54.2%  24.2  559s
# Find a violated constraint!
# Find a violated constraint!
#  11677  1595   82.04123   46    0   76.96429  118.71233  54.2%  24.2  576s
#  11689  1606  118.71233   53  321   76.96429  118.71233  54.2%  24.7  580s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  12418  1746   89.26997   64  410   76.96429  118.71233  54.2%  25.8  596s
# Find a violated constraint!
# Find a violated constraint!
#  12548  1755   86.20137   65  219   76.96429  118.71233  54.2%  25.7  608s
#  12602  1754  105.15535   68    0   76.96429  118.71233  54.2%  25.7  613s
#  12608  1758  103.91404   60  264   76.96429  118.71233  54.2%  25.6  615s
#  12622  1768  105.15535   68  148   76.96429  118.15450  53.5%  27.0  620s
#  12631  1775   96.73864   75  313   76.96429  118.03984  53.4%  27.9  625s
#  12640  1783  104.54524   64  826   76.96429  117.94735  53.2%  28.5  630s
#  12671  1803   96.73864   75  563   76.96429  117.61869  52.8%  28.4  635s
#  12692  1819   83.13451   59    0   76.96429  117.50842  52.7%  32.4  640s
#  12703  1828   96.28851   81    0   76.96429  117.22573  52.3%  33.1  645s
#  12721  1840   89.12420   84  719   76.96429  117.13134  52.2%  33.0  650s
#  12729  1848  115.36683  124  383   76.96429  116.33533  51.2%  34.6  655s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  13046  1848   98.13946  135  284   76.96429  115.04466  49.5%  35.0  671s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  13305  1807     cutoff  144        76.96429  115.04466  49.5%  34.5  684s
# Find a violated constraint!
# Find a violated constraint!
#  13642  1789     cutoff  131        76.96429  112.97424  46.8%  34.2  697s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  13711  1786   79.24458  148    -   76.96429  112.97424  46.8%  34.2  709s
#  13754  1775   78.94406  135   28   76.96429  112.97424  46.8%  34.1  710s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  13856  1789   81.63248  131  157   76.96429  105.28356  36.8%  34.0  722s
# Find a violated constraint!
# Find a violated constraint!
#  14025  1777   93.15581  133  411   76.96429  104.75184  36.1%  34.0  735s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  14317  1787   82.04733  143  159   76.96429  102.03555  32.6%  33.8  748s
# Find a violated constraint!
# Find a violated constraint!
#  14672  1788   88.65463  151    -   76.96429  102.03555  32.6%  34.0  761s
# Find a violated constraint!
# *14933  1648             153      77.3554319   98.13946  26.9%  33.7  773s
#  15129  1624     cutoff  138        77.35543   98.13946  26.9%  34.0  775s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  15191  1635   86.32066  134   71   77.35543   98.13946  26.9%  33.9  800s
# Find a violated constraint!
# Find a violated constraint!
# H15193  1530                      77.6025798   98.13946  26.5%  33.9  813s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  15300  1527     cutoff  143        77.60258   98.13946  26.5%  33.9  825s
# *15330  1339             164      78.0664703   96.61047  23.8%  33.9  837s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  15605  1358   81.27529  143   59   78.06647   95.36285  22.2%  33.8  863s
# Find a violated constraint!
# Find a violated constraint!
#  15849  1350     cutoff  174        78.06647   91.74421  17.5%  33.6  877s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  16268  1355     cutoff  154        78.06647   89.63451  14.8%  33.0  905s
# Find a violated constraint!
# Find a violated constraint!
#  16602  1362   83.71003  137  133   78.06647   87.39005  11.9%  32.8  917s
# Find a violated constraint!
# Find a violated constraint!
# *16675  1150             157      78.3037689   87.39005  11.6%  32.7  929s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  16982  1130     cutoff  163        78.30377   87.39005  11.6%  32.3  954s
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
# Find a violated constraint!
#  17347  1043     cutoff  192        78.30377   86.28603  10.2%  32.0  991s
# Find a violated constraint!
# Find a violated constraint!
#  17730  1053   83.88717  134  752   78.30377   84.58854  8.03%  31.6 1004s
# Find a violated constraint!
# Find a violated constraint!
# *17960   553             151      79.5298176   83.38602  4.85%  31.4 1016s
# Find a violated constraint!
# Find a violated constraint!
#  18878   202   79.59540  195    -   79.52982   81.01295  1.86%  30.2 1029s
# Find a violated constraint!
# Find a violated constraint!
# *18936     1             145      80.1557876   81.01295  1.07%  30.1 1041s
#
# Cutting planes:
#   Cover: 1
#   Implied bound: 43
#   Clique: 152
#   MIR: 98
#   Flow cover: 782
#   Zero half: 2
#   Lazy constraints: 53
#
# Explored 19059 nodes (573913 simplex iterations) in 1041.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 80.1558 79.5298 78.3038 ... 67.0135
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.015578758964e+01, best bound 8.015578758964e+01, gap 0.0000%
# [80.15578758963659,
#  array([1.85946463, 0.        , 2.12543892, 1.23461495, 1.50504252])]
